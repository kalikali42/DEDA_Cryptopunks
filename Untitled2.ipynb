# %% [markdown]
# <a href="https://colab.research.google.com/github/kalinakalina/DEDA_Cryptopunks/blob/web_scrape/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Helper func

# %%
def fix_dollar(x):
  x=str(x)
  x=x.replace(')', '') 
  x=x.replace('(', '') 
  x=x.replace('$', '')
  if 'M' in x:
    x=float(x.replace('M', ''))
    x=x*1000000
    return x
  return x

def fix_eth(x):
  x=str(x)
  x=x.replace('Ξ', '')
  x=float(x)
  return x

# %%
page = requests.get('https://www.larvalabs.com/cryptopunks/details/0')

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en" xmlns:bind="http://www.w3.org/1999/xhtml" xmlns:v-bind="http://www.w3.org/1999/xhtml">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>\n  <meta content="IE=11" http-equiv="X-UA-Compatible"/>\n  <link href="/public/images/favicon.ico" rel="shortcut icon" type="image/png"/>\n  <title>\n   CryptoPunks: Details for Punk #0\n  </title>\n  <meta content="CryptoPunks are 10,000 collectible characters on the Ethereum blockchain. These are the details for Punk #0" name="description">\n   <link href="/public/components/bootstrap/css/bootstrap.min.css" rel="stylesheet"/>\n   <link href="/public/components/bootstrap/css/bootstrap-theme.min.css" rel="stylesheet"/>\n   <link href="//fonts.googleapis.com/css?family=Montserrat:400,700" rel="stylesheet"/>\n   <link href="/public/font-awesome-4.7.0/css/font-awesome.min.css" rel="stylesheet"/>\n   <!-- production -->\n   <link charset="utf-8" href="/public/
# ...

# %% [markdown]
# # get Gender

# %%
accessories_list = soup.find(class_='col-md-4')
gender = accessories_list.next_sibling.next_sibling.h4.a.get_text()
print(gender)
# Out:
# 'Female'

# %%
name = accessories_list.next_sibling.next.next.next.next.next.next.next.get_text()
# Out:
# 'CryptoPunk 0'

# %%
newlist=[[]]
name = soup.find('div', class_='col-md-10 col-md-offset-1 col-xs-12')
newlist[0].append(name.h4.a.text)
    
for y in soup.find_all('div', class_='col-md-4')[1:]:
  newlist[0].append(y.a.get_text())

x = pd.DataFrame(newlist)

print(x)
# Out:
#         0                 1        2           3
# 0  Female  Green Eye Shadow  Earring  Blonde Bob

# %%
x = soup.find(class_="col-md-10 col-md-offset-1")
acc = x.find(class_='col-md-4')
acc
# Out:
# <div class="col-md-4">
# <a href="/cryptopunks/search?query=%22Green+Eye+Shadow%22">Green Eye Shadow</a>
# <br/>
# <b>271</b> punks have this.
#                     </div>

# %%
acc_1 = acc.a.get_text()
acc_2 = acc.next_sibling.next_sibling.a.get_text()

acc_3 = acc.next_sibling.next_sibling.next_sibling.next_sibling.a.get_text()


print('acc_1: ', acc_1, ', acc_2: ',acc_2, ', acc_3: ', acc_3)
# Out:
# acc_1:  Green Eye Shadow , acc_2:  Earring , acc_3:  Blonde Bob

# %%
tr_hist = soup.find_all('table')
df = pd.read_html(str(tr_hist))[0]
df['punk_nr']=punk_id
df['Txn'] = pd.to_datetime(df['Txn'])
df[['price_in_eth', 'price_in_dollars']] = df['Amount'].str.split(' ', 1, expand=True)
df.price_in_eth = df.price_in_eth.apply(fix_eth)
df.price_in_dollars = df.price_in_dollars.apply(fix_dollar)
df.drop('Amount', axis=1, inplace=True)
df.to_csv('test.csv', header=None, mode='a')
